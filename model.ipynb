# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import os
import sys

# %%
os . chdir ( "/content/gdrive/My Drive/Hackathon/WNS_Analytics_Wizard_2018/dataset")

# %%
import warnings
warnings.filterwarnings("ignore")
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import metrics
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv("test_2umaH9m.csv")
data.head(5)
# Out:
#    employee_id         department     region   education gender  \
# 0         8724         Technology  region_26  Bachelor's      m
# 1        74430                 HR   region_4  Bachelor's      f
# 2        72255  Sales & Marketing  region_13  Bachelor's      m
# 3        38562        Procurement   region_2  Bachelor's      f
# 4        64486            Finance  region_29  Bachelor's      m
#
#   recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0            sourcing                1   24                   NaN
# 1               other                1   31                   3.0
# 2               other                1   31                   1.0
# 3               other                3   31                   2.0
# 4            sourcing                1   30                   4.0
#
#    length_of_service  KPIs_met >80%  awards_won?  avg_training_score
# 0                  1              1            0                  77
# 1                  5              0            0                  51
# 2                  4              0            0                  47
# 3                  9              0            0                  65
# 4                  7              0            0                  61

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23490 entries, 0 to 23489
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   employee_id           23490 non-null  int64
#  1   department            23490 non-null  object
#  2   region                23490 non-null  object
#  3   education             22456 non-null  object
#  4   gender                23490 non-null  object
#  5   recruitment_channel   23490 non-null  object
#  6   no_of_trainings       23490 non-null  int64
#  7   age                   23490 non-null  int64
#  8   previous_year_rating  21678 non-null  float64
#  9   length_of_service     23490 non-null  int64
#  10  KPIs_met >80%         23490 non-null  int64
#  11  awards_won?           23490 non-null  int64
#  12  avg_training_score    23490 non-null  int64
# dtypes: float64(1), int64(7), object(5)
# memory usage: 2.3+ MB

# %% [markdown]
# Nulls in Education and previous_year_rating

# %%
data.describe()
# Out:
#         employee_id  no_of_trainings           age  previous_year_rating  \
# count  23490.000000     23490.000000  23490.000000          21678.000000
# mean   39041.399149         1.254236     34.782929              3.339146
# std    22640.809201         0.600910      7.679492              1.263294
# min        3.000000         1.000000     20.000000              1.000000
# 25%    19370.250000         1.000000     29.000000              3.000000
# 50%    38963.500000         1.000000     33.000000              3.000000
# 75%    58690.000000         1.000000     39.000000              4.000000
# max    78295.000000         9.000000     60.000000              5.000000
#
#        length_of_service  KPIs_met >80%   awards_won?  avg_training_score
# count       23490.000000   23490.000000  23490.000000        23490.000000
# mean            5.810387       0.358834      0.022776           63.263133
# std             4.207917       0.479668      0.149191           13.411750
# min             1.000000       0.000000      0.000000           39.000000
# 25%             3.000000       0.000000      0.000000           51.000000
# 50%             5.000000       0.000000      0.000000           60.000000
# 75%             7.000000       1.000000      0.000000           76.000000
# max            34.000000       1.000000      1.000000           99.000000

# %% [markdown]
# ## Null value treatment for previous year rating

# %%
data["previous_year_rating"].fillna(data.groupby(["department"])["previous_year_rating"].transform("mean").round(0).astype(int), inplace = True)

# %% [markdown]
# ## Null value for Education

# %%
data["education"].fillna("X", inplace = True)

# %% [markdown]
# # Outlier Treatment

# %%
data.describe(percentiles=[0.005, 0.05, 0.25, 0.75, 0.95, 0.995])
# Out:
#         employee_id  no_of_trainings           age  previous_year_rating  \
# count  23490.000000     23490.000000  23490.000000          23490.000000
# mean   39041.399149         1.254236     34.782929              3.343806
# std    22640.809201         0.600910      7.679492              1.221297
# min        3.000000         1.000000     20.000000              1.000000
# 0.5%     391.670000         1.000000     22.000000              1.000000
# 5%      3913.950000         1.000000     25.000000              1.000000
# 25%    19370.250000         1.000000     29.000000              3.000000
# 50%    38963.500000         1.000000     33.000000              3.000000
# 75%    58690.000000         1.000000     39.000000              4.000000
# 95%    74329.550000         2.000000     51.000000              5.000000
# 99.5%  77899.220000         4.000000     59.000000              5.000000
# max    78295.000000         9.000000     60.000000              5.000000
#
#        length_of_service  KPIs_met >80%   awards_won?  avg_training_score
# count       23490.000000   23490.000000  23490.000000        23490.000000
# mean            5.810387       0.358834      0.022776           63.263133
# std             4.207917       0.479668      0.149191           13.411750
# min             1.000000       0.000000      0.000000           39.000000
# 0.5%            1.000000       0.000000      0.000000           44.000000
# 5%              1.000000       0.000000      0.000000           47.000000
# 25%             3.000000       0.000000      0.000000           51.000000
# 50%             5.000000       0.000000      0.000000           60.000000
# 75%             7.000000       1.000000      0.000000           76.000000
# 95%            15.000000       1.000000      0.000000           86.000000
# 99.5%          23.000000       1.000000      1.000000           94.000000
# max            34.000000       1.000000      1.000000           99.000000

# %% [markdown]
# #### Average Training Score

# %%
data["avg_training_score"] = data["avg_training_score"].apply(lambda x : x if x <= 94.0 else 94.0)
data["avg_training_score"] = data["avg_training_score"].apply(lambda x : x if x >= 44.0 else 44.0)

# %% [markdown]
# #### Number of Trainings

# %%
data["no_of_trainings"] = data["no_of_trainings"].apply(lambda x : x if x <= 4.0 else 4.0)

# %% [markdown]
# #### Age

# %%
data["age"] = data["age"].apply(lambda x : 59.0 if x>59.0 else x)
data["age"] = data["age"].apply(lambda x : 22.0 if x<22.0 else x)

# %% [markdown]
# #### Length of service

# %%
data["length_of_service"] = data["length_of_service"].apply(lambda x : x if x<=24.0 else 24.0)

# %% [markdown]
# # Feature Engineering

# %%
data["new_score"] = (max(data["age"]) - data["age"])*(max(data["length_of_service"]) - data["length_of_service"])*data["previous_year_rating"]

# %%
data["new_score"] = pd.cut(data["new_score"], bins = 10)
data
# Out:
#        employee_id         department     region         education gender  \
# 0             8724         Technology  region_26        Bachelor's      m
# 1            74430                 HR   region_4        Bachelor's      f
# 2            72255  Sales & Marketing  region_13        Bachelor's      m
# 3            38562        Procurement   region_2        Bachelor's      f
# 4            64486            Finance  region_29        Bachelor's      m
# ...            ...                ...        ...               ...    ...
# 23485        53478              Legal   region_2   Below Secondary      m
# 23486        25600         Technology  region_25        Bachelor's      m
# 23487        45409                 HR  region_16        Bachelor's      f
# 23488         1186        Procurement  region_31        Bachelor's      m
# 23489         5973         Technology  region_17  Master's & above      m
#
#       recruitment_channel  no_of_trainings   age  previous_year_rating  \
# 0                sourcing              1.0  24.0                   3.0
# 1                   other              1.0  31.0                   3.0
# 2                   other              1.0  31.0                   1.0
# 3                   other              3.0  31.0                   2.0
# 4                sourcing              1.0  30.0                   4.0
# ...                   ...              ...   ...                   ...
# 23485            sourcing              1.0  24.0                   3.0
# 23486            sourcing              1.0  31.0                   3.0
# 23487            sourcing              1.0  26.0                   4.0
# 23488            sourcing              3.0  27.0                   3.0
# 23489               other              3.0  40.0                   5.0
#
#        length_of_service  KPIs_met >80%  awards_won?  avg_training_score  \
# 0                    1.0              1            0                77.0
# 1                    5.0              0            0                51.0
# 2                    4.0              0            0                47.0
# 3                    9.0              0            0                65.0
# 4                    7.0              0            0                61.0
# ...                  ...            ...          ...                 ...
# 23485                1.0              0            0                61.0
# 23486                7.0              0            0                74.0
# 23487                4.0              0            0                50.0
# 23488                1.0              0            0                70.0
# 23489                5.0              1            0                89.0
#
#               new_score
# 0      (2127.5, 2553.0]
# 1      (1276.5, 1702.0]
# 2        (425.5, 851.0]
# 3        (425.5, 851.0]
# 4      (1702.0, 2127.5]
# ...                 ...
# 23485  (2127.5, 2553.0]
# 23486  (1276.5, 1702.0]
# 23487  (2553.0, 2978.5]
# 23488  (2127.5, 2553.0]
# 23489  (1702.0, 2127.5]
#
# [23490 rows x 14 columns]

# %%
for key,row in data.iterrows():
    data.loc[key,'start'] = row['new_score'].left
    data.loc[key,'end'] = row['new_score'].right

# %%
data['mean_new_score'] = (data["start"] + data["end"])/2

# %%
data["los_age"] = data["length_of_service"]/data["age"]

# %% [markdown]
# ### New feature - Department wise above or below training score

# %%
data.columns
# Out:
# Index(['employee_id', 'department', 'region', 'education', 'gender',
#        'recruitment_channel', 'no_of_trainings', 'age', 'previous_year_rating',
#        'length_of_service', 'KPIs_met >80%', 'awards_won?',
#        'avg_training_score', 'new_score', 'start', 'end', 'mean_new_score',
#        'los_age'],
#       dtype='object')

# %%
temp1 = data[["department", "avg_training_score"]]
temp1
# Out:
#               department  avg_training_score
# 0             Technology                77.0
# 1                     HR                51.0
# 2      Sales & Marketing                47.0
# 3            Procurement                65.0
# 4                Finance                61.0
# ...                  ...                 ...
# 23485              Legal                61.0
# 23486         Technology                74.0
# 23487                 HR                50.0
# 23488        Procurement                70.0
# 23489         Technology                89.0
#
# [23490 rows x 2 columns]

# %%
temp = data[["department", "avg_training_score"]].groupby(["department"]).mean()
#temp.loc[row["department"], "avg_training_score"]
#temp.loc[row["department"], "avg_training_score"]
temp
# Out:
#                    avg_training_score
# department
# Analytics                   84.525658
# Finance                     60.313474
# HR                          50.306912
# Legal                       59.575281
# Operations                  60.287573
# Procurement                 70.133775
# R&D                         84.409091
# Sales & Marketing           50.095967
# Technology                  79.847227

# %%
temp1 = data[["department", "avg_training_score"]]
temp1
# Out:
#               department  avg_training_score
# 0             Technology                77.0
# 1                     HR                51.0
# 2      Sales & Marketing                47.0
# 3            Procurement                65.0
# 4                Finance                61.0
# ...                  ...                 ...
# 23485              Legal                61.0
# 23486         Technology                74.0
# 23487                 HR                50.0
# 23488        Procurement                70.0
# 23489         Technology                89.0
#
# [23490 rows x 2 columns]

# %%
row["avg_training_score"] > temp.loc[row["department"]].iloc[0]
# Out:
# True

# %%
temp1["training_score_better"] = temp1.apply(lambda row : 1 if (row["avg_training_score"] > temp.loc[row["department"]].iloc[0]) else 0, axis = 1)
data["training_score_better"] = temp1["training_score_better"]
data
# Out:
#        employee_id         department     region         education gender  \
# 0             8724         Technology  region_26        Bachelor's      m
# 1            74430                 HR   region_4        Bachelor's      f
# 2            72255  Sales & Marketing  region_13        Bachelor's      m
# 3            38562        Procurement   region_2        Bachelor's      f
# 4            64486            Finance  region_29        Bachelor's      m
# ...            ...                ...        ...               ...    ...
# 23485        53478              Legal   region_2   Below Secondary      m
# 23486        25600         Technology  region_25        Bachelor's      m
# 23487        45409                 HR  region_16        Bachelor's      f
# 23488         1186        Procurement  region_31        Bachelor's      m
# 23489         5973         Technology  region_17  Master's & above      m
#
#       recruitment_channel  no_of_trainings   age  previous_year_rating  \
# 0                sourcing              1.0  24.0                   3.0
# 1                   other              1.0  31.0                   3.0
# 2                   other              1.0  31.0                   1.0
# 3                   other              3.0  31.0                   2.0
# 4                sourcing              1.0  30.0                   4.0
# ...                   ...              ...   ...                   ...
# 23485            sourcing              1.0  24.0                   3.0
# 23486            sourcing              1.0  31.0                   3.0
# 23487            sourcing              1.0  26.0                   4.0
# 23488            sourcing              3.0  27.0                   3.0
# 23489               other              3.0  40.0                   5.0
#
#        length_of_service  KPIs_met >80%  awards_won?  avg_training_score  \
# 0                    1.0              1            0                77.0
# 1                    5.0              0            0                51.0
# 2                    4.0              0            0                47.0
# 3                    9.0              0            0                65.0
# 4                    7.0              0            0                61.0
# ...                  ...            ...          ...                 ...
# 23485                1.0              0            0                61.0
# 23486                7.0              0            0                74.0
# 23487                4.0              0            0                50.0
# 23488                1.0              0            0                70.0
# 23489                5.0              1            0                89.0
#
#               new_score   start     end  mean_new_score   los_age  \
# 0      (2127.5, 2553.0]  2127.5  2553.0         2340.25  0.041667
# 1      (1276.5, 1702.0]  1276.5  1702.0         1489.25  0.161290
# 2        (425.5, 851.0]   425.5   851.0          638.25  0.129032
# 3        (425.5, 851.0]   425.5   851.0          638.25  0.290323
# 4      (1702.0, 2127.5]  1702.0  2127.5         1914.75  0.233333
# ...                 ...     ...     ...             ...       ...
# 23485  (2127.5, 2553.0]  2127.5  2553.0         2340.25  0.041667
# 23486  (1276.5, 1702.0]  1276.5  1702.0         1489.25  0.225806
# 23487  (2553.0, 2978.5]  2553.0  2978.5         2765.75  0.153846
# 23488  (2127.5, 2553.0]  2127.5  2553.0         2340.25  0.037037
# 23489  (1702.0, 2127.5]  1702.0  2127.5         1914.75  0.125000
#
#        training_score_better
# 0                          0
# 1                          1
# 2                          0
# 3                          0
# 4                          1
# ...                      ...
# 23485                      1
# 23486                      0
# 23487                      0
# 23488                      0
# 23489                      1
#
# [23490 rows x 19 columns]

# %% [markdown]
# # One hot encoding and Label encoding

# %%
from sklearn import preprocessing

# %%
data.columns
data.drop(["start", "end", "new_score", "mean_new_score"], axis = 1, inplace = True)

# %%
copy_data = data.copy()

# %%
#region_order = copy_data[copy_data["is_promoted"] == 1].groupby(by = ["region"])["is_promoted"].count().sort_values()

# %%
label_encoder = pd.read_csv("label_encoding_order.csv").set_index("region")
label_encoder
# Out:
#             0
# region
# region_18   0
# region_9    1
# region_34   1
# region_33   2
# region_21   3
# region_24   3
# region_6    4
# region_12   5
# region_5    6
# region_3    7
# region_32   8
# region_29   9
# region_20  10
# region_10  11
# region_19  12
# region_8   12
# region_1   13
# region_30  14
# region_14  15
# region_11  16
# region_16  17
# region_25  18
# region_17  19
# region_31  20
# region_27  21
# region_23  22
# region_26  23
# region_28  24
# region_15  25
# region_13  26
# region_4   27
# region_7   28
# region_22  29
# region_2   30

# %%
copy_data["region"] = copy_data["region"].apply(lambda x : label_encoder.loc[x])
copy_data
# Out:
#        employee_id         department  region         education gender  \
# 0             8724         Technology      23        Bachelor's      m
# 1            74430                 HR      27        Bachelor's      f
# 2            72255  Sales & Marketing      26        Bachelor's      m
# 3            38562        Procurement      30        Bachelor's      f
# 4            64486            Finance       9        Bachelor's      m
# ...            ...                ...     ...               ...    ...
# 23485        53478              Legal      30   Below Secondary      m
# 23486        25600         Technology      18        Bachelor's      m
# 23487        45409                 HR      17        Bachelor's      f
# 23488         1186        Procurement      20        Bachelor's      m
# 23489         5973         Technology      19  Master's & above      m
#
#       recruitment_channel  no_of_trainings   age  previous_year_rating  \
# 0                sourcing              1.0  24.0                   3.0
# 1                   other              1.0  31.0                   3.0
# 2                   other              1.0  31.0                   1.0
# 3                   other              3.0  31.0                   2.0
# 4                sourcing              1.0  30.0                   4.0
# ...                   ...              ...   ...                   ...
# 23485            sourcing              1.0  24.0                   3.0
# 23486            sourcing              1.0  31.0                   3.0
# 23487            sourcing              1.0  26.0                   4.0
# 23488            sourcing              3.0  27.0                   3.0
# 23489               other              3.0  40.0                   5.0
#
#        length_of_service  KPIs_met >80%  awards_won?  avg_training_score  \
# 0                    1.0              1            0                77.0
# 1                    5.0              0            0                51.0
# 2                    4.0              0            0                47.0
# 3                    9.0              0            0                65.0
# 4                    7.0              0            0                61.0
# ...                  ...            ...          ...                 ...
# 23485                1.0              0            0                61.0
# 23486                7.0              0            0                74.0
# 23487                4.0              0            0                50.0
# 23488                1.0              0            0                70.0
# 23489                5.0              1            0                89.0
#
#         los_age  training_score_better
# 0      0.041667                      0
# 1      0.161290                      1
# 2      0.129032                      0
# 3      0.290323                      0
# 4      0.233333                      1
# ...         ...                    ...
# 23485  0.041667                      1
# 23486  0.225806                      0
# 23487  0.153846                      0
# 23488  0.037037                      0
# 23489  0.125000                      1
#
# [23490 rows x 15 columns]

# %%
#One hot encoding
col_str = list(copy_data.columns[(copy_data.dtypes == object) | (copy_data.dtypes == 'category')])
#col_str.remove("gender")
col_str.remove("gender")
col_str
# Out:
# ['department', 'education', 'recruitment_channel']

# %%
copy_data = pd.get_dummies(copy_data, columns = col_str, drop_first = False)
copy_data = pd.get_dummies(copy_data, columns = ["gender"], drop_first = True)
copy_data.shape
# Out:
# (23490, 28)

# %%
# Normalize the data
from sklearn import preprocessing
# Drop the target variable, ID, and non-relevant features
data_normalized = copy_data.drop(['employee_id'], axis=1)
data_normalized = pd.DataFrame(preprocessing.scale(data_normalized), columns = data_normalized.columns)
data_normalized.describe()
# Out:
#              region  no_of_trainings           age  previous_year_rating  \
# count  2.349000e+04     2.349000e+04  2.349000e+04          2.349000e+04
# mean  -6.049747e-17    -1.857272e-16  4.128952e-16         -4.960792e-17
# std    1.000021e+00     1.000021e+00  1.000021e+00          1.000021e+00
# min   -2.696053e+00    -4.408731e-01 -1.669856e+00         -1.919152e+00
# 25%   -6.532647e-01    -4.408731e-01 -7.555924e-01         -2.815147e-01
# 50%    4.282116e-01    -4.408731e-01 -2.331559e-01         -2.815147e-01
# 75%    7.887037e-01    -4.408731e-01  5.504988e-01          5.373041e-01
# max    9.088677e-01     4.876315e+00  3.162681e+00          1.356123e+00
#
#        length_of_service  KPIs_met >80%   awards_won?  avg_training_score  \
# count       2.349000e+04   2.349000e+04  2.349000e+04        2.349000e+04
# mean       -5.943876e-17   1.016357e-16  1.905670e-17       -1.228099e-16
# std         1.000021e+00   1.000021e+00  1.000021e+00        1.000021e+00
# min        -1.158517e+00  -7.481025e-01 -1.526646e-01       -1.439914e+00
# 25%        -6.754761e-01  -7.481025e-01 -1.526646e-01       -9.165338e-01
# 50%        -1.924350e-01  -7.481025e-01 -1.526646e-01       -2.436169e-01
# 75%         2.906061e-01   1.336715e+00 -1.526646e-01        9.526799e-01
# max         4.396455e+00   1.336715e+00  6.550309e+00        2.298514e+00
#
#             los_age  training_score_better  ...  department_Sales & Marketing  \
# count  2.349000e+04           2.349000e+04  ...                  2.349000e+04
# mean  -2.395700e-16           4.386066e-18  ...                 -3.629848e-17
# std    1.000021e+00           1.000021e+00  ...                  1.000021e+00
# min   -1.524506e+00          -8.340633e-01  ...                 -6.724887e-01
# 25%   -8.085117e-01          -8.340633e-01  ...                 -6.724887e-01
# 50%   -1.746808e-01          -8.340633e-01  ...                 -6.724887e-01
# 75%    6.352142e-01           1.198950e+00  ...                  1.487014e+00
# max    3.995417e+00           1.198950e+00  ...                  1.487014e+00
#
#        department_Technology  education_Bachelor's  education_Below Secondary  \
# count           2.349000e+04          2.349000e+04               2.349000e+04
# mean            7.864671e-17          3.871838e-17               6.563975e-17
# std             1.000021e+00          1.000021e+00               1.000021e+00
# min            -3.834432e-01         -1.403178e+00              -1.271978e-01
# 25%            -3.834432e-01         -1.403178e+00              -1.271978e-01
# 50%            -3.834432e-01          7.126681e-01              -1.271978e-01
# 75%            -3.834432e-01          7.126681e-01              -1.271978e-01
# max             2.607948e+00          7.126681e-01               7.861774e+00
#
#        education_Master's & above   education_X  recruitment_channel_other  \
# count                2.349000e+04  2.349000e+04               2.349000e+04
# mean                 3.266863e-17 -3.992833e-17              -8.106660e-17
# std                  1.000021e+00  1.000021e+00               1.000021e+00
# min                 -6.187920e-01 -2.145824e-01              -1.120737e+00
# 25%                 -6.187920e-01 -2.145824e-01              -1.120737e+00
# 50%                 -6.187920e-01 -2.145824e-01               8.922703e-01
# 75%                  1.616052e+00 -2.145824e-01               8.922703e-01
# max                  1.616052e+00  4.660215e+00               8.922703e-01
#
#        recruitment_channel_referred  recruitment_channel_sourcing  \
# count                  2.349000e+04                  2.349000e+04
# mean                   4.597807e-17                  4.355818e-17
# std                    1.000021e+00                  1.000021e+00
# min                   -1.399125e-01                 -8.580619e-01
# 25%                   -1.399125e-01                 -8.580619e-01
# 50%                   -1.399125e-01                 -8.580619e-01
# 75%                   -1.399125e-01                  1.165417e+00
# max                    7.147325e+00                  1.165417e+00
#
#            gender_m
# count  2.349000e+04
# mean  -5.686762e-17
# std    1.000021e+00
# min   -1.551551e+00
# 25%   -1.551551e+00
# 50%    6.445163e-01
# 75%    6.445163e-01
# max    6.445163e-01
#
# [8 rows x 27 columns]

# %% [markdown]
# #Testing our model on dataset

# %%
feature_cols = copy_data.drop(['employee_id'], axis = 1).columns
X_test = data_normalized[feature_cols]

# %%
import joblib

model = joblib.load('model_xgb.pkl')

# %%
test_predictions = model.predict(X_test)

# %%
len(test_predictions)
# Out:
# 23490

# %%
data["is_promoted"] = test_predictions

# %%
data[["employee_id", "is_promoted"]].set_index("employee_id").to_csv("final_result.csv", sep=',', index=True, encoding='utf-8')
